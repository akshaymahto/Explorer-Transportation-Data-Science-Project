# %% [markdown]
# # 🚗 **Welcome to the <font color='crimson'>** **Explorer Transportation Data Science Project! 🚗**</font>
#  Hosted by the [Northeast Big Data Innovation Hub](https://nebigdatahub.org/about) & [National Student Data Corps](https://nebigdatahub.org/nsdc), in collaboration with the [U.S. Department of Transportation Federal Highway Administration](https://highways.dot.gov/).
#
#
# ---

# %% [markdown]
# ## <font color='crimson'>**Project Information and Background:**</font>

# %% [markdown]
# **Project Description:**
#
# By participating in this project, you are joining a
# community of transportation data science learners interested in making roads safer for vulnerable road users.
#
# The Explorer TDSP has six Milestones, including guided transportation research into a community of interest. Each Milestone can take 1-5 hours, or less, depending on your level of experience.
#
# To learn more about this project, including key highlights, incentives, and important links, [review the TDSP Webpage here](https://nebigdatahub.org/nsdc/tdsp/)!

# %% [markdown]
# ## <font color='crimson'>**How to Get Started:**</font>

# %% [markdown]
# In order to work within this Google Colab Notebook, **please start by clicking on "File" in the top left corner of your notebook, and then "Save a copy in Drive." Rename the file to "Explorer TDSP - Your Full Name."** This will save a copy of the notebook in your personal Google Drive.
#
# You may now begin!

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <font color='crimson'>**A Quick Introduction to Google Colab**</font>

# %% [markdown]
# Read below for a Google Colab QuickStart:
# - Google Colab is a Python Notebook environment built by Google that's free for all.
# - Colab Notebooks are made up of cells; cells can be either *text* or *code* cells. You can click the +code or +text button at the top of the Notebook to create a new cell.
# - Text cells use a format called [Markdown](https://www.markdownguide.org/getting-started/). Knowledge of Markdown is not required for this project. However, if you'd like to learn more, [check out this Cheatsheet!](https://www.markdownguide.org/cheat-sheet/)
# - Python code is executed in *code* cells. When you want to run your code, hover your cursor over the square brackets in the top left corner of your code cell. You'll notice a play button pop up! (▶) Click the play button to run the code in that cell. Code cells run one at a time.
# - The memory shared across your notebook is called the *Runtime*. You can think of a Runtime as a "code session" where everything you create and execute is temporarily stored.
# - Runtimes will persist for a short period of time, so you are safe if you need to refresh the page, but Google will shutdown a Runtime after enough time has passed. Everything that you have printed out will remain within your Notebook even if the runtime is disconnected.
#
# If this is your first time using Google Colab, we highly recommend reviewing the [NSDC's *Using Google Colab Guide*](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf) before continuing. For a more comprehensive guide, see [Colab's *Welcome To Colaboratory* walkthrough.](https://colab.research.google.com/github/prites18/NoteNote/blob/master/Welcome_To_Colaboratory.ipynb)

# %% [markdown]
# ## <font color='crimson'>**An Introduction to Python Programming**</font>

# %% [markdown]
# Python is a programming language often used to analyze data.
#
# Python is open-source, which means it's free to use and distribute, even for commercial purposes. Python's versatility allows it to be used for web development, data visualization, artificial intelligence, scientific computing, and more.
#
# Python's extensive standard library, along with its powerful third-party packages, enable developers and data scientists to perform a vast array of tasks.
#
# For those looking to dive deeper into Python, here are some valuable resources:
# - [The Official Python Documentation](https://docs.python.org/3/) – Offers comprehensive guides and reference materials for Python leaners.
# - [Real Python](https://realpython.com/) – Provides tutorials and articles for Python developers of all skill levels.
# - [PyCon](https://pycon.org/) – The largest annual gathering for the Python community, which is useful for learning from experts and discovering the latest developments in the Python ecosystem.
# - [Python for Everybody](https://www.py4e.com/) – A book and website by Dr. Charles Severance that offers a free course on Python for beginners.

# %% [markdown]
# **Let's review some essential Python Functions!**
#
# Here are some key functions you'll frequently encounter:
#
# 1. **`head()`**: This function is crucial for getting a quick overview of your dataset. By default, it returns the first five rows, offering a snapshot of your data's structure and values.
#
# 2. **`describe()`**: This provides a summary of the statistical characteristics of your dataset. It's particularly useful for gaining insights into the distribution, mean, standard deviation, and range of numerical columns.
#
# 3. **`sum()`**: This calculates the total sum of a column or a series of numbers, proving essential for quick calculations and aggregations in data analysis.
#
# 4. **`isnull()`**: This helps identify missing or null values in your dataset, allowing for effective data cleaning and preprocessing.
#
# 5. **`value_counts()`**: Understanding the frequency of various values in your dataset is a common task in data science. The `value_counts()` function makes this easy by counting the occurrence of each unique value in a column.
#
# Now that you've reviewed these important concepts, let's dive in to the project!

# %% [markdown]
# ## <font color='crimson'>**Milestone #1 - Data Preparation**</font>
# GOAL: The main goal of this milestone is to set up your environment, install the required packages, learn how to access data and do some basic exploratory data analysis.

# %% [markdown]
# **Step 1:** Setting up libraries and installing packages
#
# A **library** is a collection of code that you can use in your programs, while a **package** is a folder that contains libraries or other packages, organized for easy use.
#
# To install a library, we'll use the following format:
# ```python
#  import <library name> as <shortname>
# ```
# We use a *short name* since it is easier to refer to the package to access functions and also to refer to subpackages within the library. Think of it as a nickname for easier reference!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# These are the libraries that will help us throughout this project. We invite you to research each library for a better understanding.
#
# We encourage you to read more about the important and most commonly used libraries like Pandas, Matplotlib, and Seaborn and write a few lines in your own words about what they do. [You may use the Data Science Resource Repository (DSRR) to find resources to get started!](https://nebigdatahub.org/nsdc/data-science-resource-repository/)

# %% [markdown]
# **TO DO:** Write a few lines about what each library does:
#
#
#
#
# > * Pandas:
# Pandas is the most powerful Python library used for data manipulation and analysis. It offers data structures- DataFrames and Series-to efficiently handle and analyze structured data. It allows one to execute lots of operations over datasets, cleaning, filtering, or aggregating.
# > * Matplotlib:
# Matplotlib is a plotting library that, in Python, enables the creation of static, interactive, and animated visualizations. It provides a variety of chart types, including line plots, bar graphs, scatter plots, and many more, with very precise control over formatting and customization.
# > * Seaborn:
# Seaborn is built on top of Matplotlib and has focused on making the visualization of statistical data more intuitive and attractive. It further simplifies the creation of complex plots such as heatmaps, pair plots, and violin plots while integrating with Pandas for easy data exploration and visualization.

# %% [markdown]
# **Step 2:** Let’s access our data. We will be using the [NYC OpenData Motor Vehicle Collisions - Crashes dataset](https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95). According to NYC Open Data, "each row represents a crash event. The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC." If you need a reminder on how to upload your dataset, [please review helpful hints here.](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf)
#
# Since this is a large dataset, we highly recommend that you upload your data by [mounting your Google Drive](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=u22w3BFiOveA).
#
# To mount your Google Drive, begin by finding the folder icon on the left side of your screen. When you click on this folder icon, you will open the Files window. Click on the icon at the top of the Files window that says "Mount Drive" as you hover over it.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next, we will read the data using the `pd.read_csv` function.
# Ensure that you've downloaded the dataset from NYC OpenData, and uploaded the dataset to your Google Drive.

# %% [markdown]
# Hint: Your data's file path describes the location of where your data lives. To locate your data's file path, click on the folder/file-shaped icon on the left side of the Notebook. You'll notice a folder labeled "drive." Search for your Motor Vehicle Collisions Dataset within that folder. Right click on your Dataset to "copy path." Paste that path below.

# %%
# TODO: Read the data using pandas read_csv function
data = pd.read_csv("/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250103.csv")
# Out:
# <ipython-input-3-2e2706bdaf86>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250103.csv")

# %% [markdown]
# **Step 3:** Let's see what the data looks like. We can use the `head` function which returns the first 5 rows of the dataset.

# %%
# TODO: Print the first 5 rows of the data using head function of pandas
print(data.head())
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# 1                      NaN  ...                            NaN
# 2                      NaN  ...                    Unspecified
# 3  1211      LORING AVENUE  ...                            NaN
# 4                      NaN  ...                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  VEHICLE TYPE CODE 1  \
# 0                            NaN       4455765                Sedan
# 1                            NaN       4513547                Sedan
# 2                            NaN       4541903                Sedan
# 3                            NaN       4456314                Sedan
# 4                            NaN       4486609                  NaN
#
#    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                Sedan                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2        Pick-up Truck                  NaN                 NaN
# 3                  NaN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
#   VEHICLE TYPE CODE 5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %%
# TODO: Describe the data using the describe function of pandas
desc_stats = data.describe()
print(desc_stats)
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.907120e+06  1.907120e+06               2.146646e+06
# mean   4.062064e+01 -7.373927e+01               3.194681e-01
# std    2.050499e+00  3.841687e+00               7.079647e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066756e+01 -7.397469e+01               0.000000e+00
# 50%    4.072055e+01 -7.392705e+01               0.000000e+00
# 75%    4.076962e+01 -7.386674e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              2.146633e+06                   2.146664e+06
# mean               1.541950e-03                   5.810644e-02
# std                4.144304e-02                   2.471785e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# 50%                0.000000e+00                   0.000000e+00
# 75%                0.000000e+00                   0.000000e+00
# max                8.000000e+00                   2.700000e+01
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  2.146664e+06               2.146664e+06
# mean                   7.621127e-04               2.795640e-02
# std                    2.816397e-02               1.669818e-01
# min                    0.000000e+00               0.000000e+00
# 25%                    0.000000e+00               0.000000e+00
# 50%                    0.000000e+00               0.000000e+00
# 75%                    0.000000e+00               0.000000e+00
# max                    6.000000e+00               4.000000e+00
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              2.146664e+06                2.146664e+06
# mean               1.206523e-04                2.291896e-01
# std                1.102586e-02                6.691165e-01
# min                0.000000e+00                0.000000e+00
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                0.000000e+00
# max                2.000000e+00                4.300000e+01
#
#        NUMBER OF MOTORIST KILLED  COLLISION_ID
# count               2.146664e+06  2.146664e+06
# mean                6.344728e-04  3.212324e+06
# std                 2.754842e-02  1.507056e+06
# min                 0.000000e+00  2.200000e+01
# 25%                 0.000000e+00  3.172786e+06
# 50%                 0.000000e+00  3.709598e+06
# 75%                 0.000000e+00  4.246494e+06
# max                 5.000000e+00  4.783389e+06

# %% [markdown]
# The information above is currently formatted in scientific notation. Need a refresher? [Review how to analyze and convert to and from scientific notation here!](https://www.mathsisfun.com/numbers/scientific-notation.html)
#
# 1. Latitude & Longitude: The latitude and longitude indicate where the crashes are occurring. However, there are some data points with latitude and longitude values of 0, which is likely due to missing or inaccurate data.
#
# 2. Number of Persons Injured: On average, each crash has around 0.305 injuries. The maximum number of injuries in a single crash is 43.
#
# 3. Number of Persons Killed: Fatalities are rare, with an average of 0.00146 deaths per crash. The maximum number of deaths in one crash is 8.
#
# 4. Number of Pedestrians, Cyclists, and Motorists Injured/Killed: These columns provide a breakdown of the injuries and fatalities by type of individual involved.
#
# 5. Collision ID: This is a unique identifier for each crash.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #2 - Data Ethics, Pre-Processing, and Exploration** </font>
# GOAL: The main goal of this milestone is to assess the dataset, find missing values, and decide what to do with those missing data points.

# %% [markdown]
# **Step 1:**
# Before we begin assessing our data for missing values, it is important that we understand the ethical implications surrounding data processing. To best prepare yourself for this module, review one or more of the following resources:
# - [Data Science Ethics Flashcard Video Series](https://youtube.com/playlist?list=PLNs9ZO9jGtUB7XTjXy-ttoo2QSLld9SrV&feature=shared)
# - [What Do I Need to Understand about Data Ethics?](https://www.youtube.com/watch?v=Efy8htCDueE)
# -[Introduction to Data Cleaning](https://www.youtube.com/watch?v=t8WkoGLkdTk)
#
# **TO DO:** Based on the resources above and outside knowledge, what are some potential bias issues related to the availability of data from well-resourced communities as compared to under-resourced communities? How might bias show up in our dataset?
#
# > Answer here:
# some potential bias issues related to the availability of data from well-resourced communities as compared to under-resourced communities:
#
# Systemic Inequalities in Resource Distribution:
# This makes some areas that are already well-resourced receive most of the policy decisions or infrastructural improvements because of the total lack or bad data collected in under-resourced communities. This creates an aggravating self-reinforcing feedback loop, further under-serving these communities.
#
# Technological Barriers and Digital Divide:
# Communities with limited technological access cannot utilize tools like apps to report crashes, road hazards, or injuries, unlike other more technologically advanced communities that can easily generate such data.
#
# Sampling Bias:
# If data come only from strong surveillance areas, this will eventually lead to skewed datasets, representing the pattern of and drawing conclusions on representatively selected areas alone. Such a sample will yield a dataset not indicating the exact patterns of underrepresented groups.
#
#  How might bias show up in our dataset:
#
# Geographical bias: There are boroughs or zip codes that have more complete crash reports due to better resource availability.
# Incomplete Data: Missing values on key features of the data, including injury severity and demographic information, could be more likely to happen with lesser-resourced areas.
# Biased Policy Implications: If communities that are under-resourced are underrepresented, interventions based on data could also focus on areas which, in fact, have higher apparent crash rates simply because of better reporting.

# %% [markdown]
# **Step 2:**
# Check the dataset for missing values.

# %%
#TODO: Leverage the isnull() and sum() functions to find the number of missing values in each column
missing_values = data.isnull().sum()

#TODO: Turn the missing value counts into percentages
missing_values_percentage = (missing_values / len(data)) * 100

#TODO: Return counts and percentages of missing values in each column
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage (%)': missing_values_percentage})
missing_data.sort_values(by='Percentage (%)', ascending=False)
# Out:
#                                Missing Values  Percentage (%)
# VEHICLE TYPE CODE 5                   2137355       99.566350
# CONTRIBUTING FACTOR VEHICLE 5         2137059       99.552562
# VEHICLE TYPE CODE 4                   2112763       98.420759
# CONTRIBUTING FACTOR VEHICLE 4         2111505       98.362156
# VEHICLE TYPE CODE 3                   1997909       93.070411
# CONTRIBUTING FACTOR VEHICLE 3         1992088       92.799246
# OFF STREET NAME                       1778132       82.832339
# CROSS STREET NAME                      818433       38.125808
# ZIP CODE                               665824       31.016684
# BOROUGH                                665561       31.004433
# ON STREET NAME                         460905       21.470756
# VEHICLE TYPE CODE 2                    420480       19.587602
# CONTRIBUTING FACTOR VEHICLE 2          338547       15.770843
# LOCATION                               239544       11.158896
# LONGITUDE                              239544       11.158896
# LATITUDE                               239544       11.158896
# VEHICLE TYPE CODE 1                     14903        0.694240
# CONTRIBUTING FACTOR VEHICLE 1            7296        0.339876
# NUMBER OF PERSONS KILLED                   31        0.001444
# NUMBER OF PERSONS INJURED                  18        0.000839
# COLLISION_ID                                0        0.000000
# CRASH DATE                                  0        0.000000
# NUMBER OF MOTORIST KILLED                   0        0.000000
# NUMBER OF MOTORIST INJURED                  0        0.000000
# NUMBER OF CYCLIST KILLED                    0        0.000000
# CRASH TIME                                  0        0.000000
# NUMBER OF PEDESTRIANS KILLED                0        0.000000
# NUMBER OF PEDESTRIANS INJURED               0        0.000000
# NUMBER OF CYCLIST INJURED                   0        0.000000

# %% [markdown]
# Here's an overview of the missing values in the dataset:
#
# Columns like VEHICLE TYPE CODE 5, CONTRIBUTING FACTOR VEHICLE 5, VEHICLE TYPE CODE 4, and so on have a high percentage of missing values. This is expected since not all crashes involve multiple vehicles or factors.
#
# OFF STREET NAME and CROSS STREET NAME have significant missing values. This could be due to crashes occurring in locations where these details aren't applicable or weren't recorded.
#
# ZIP CODE, BOROUGH, and ON STREET NAME also have missing values. This might be due to incomplete data entry or crashes occurring in areas where these specifics aren't easily determinable.
#
# LOCATION, LATITUDE, and LONGITUDE have the same count of missing values, indicating that when one is missing, the others are likely missing as well.

# %% [markdown]
# **Step 3:** Create a bar chart to display the top 10 contributing factors (e.g. backing up unsafely, unsafe lane changing, etc.) to crashes within the dataset.

# %%
#TODO: Plot a Bar Chart

top_factors = data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)


plt.figure(figsize=(12, 7))
# TODO: Plotting the top contributing factors, fill in x as the index field of the variable 'top_factors'
sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")
plt.title('Top 10 Contributing Factors to crashes', fontsize=16)
plt.xlabel('Contributing Factor', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-7-7d37ac3b9295>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")

# %% [markdown]
# :**TO DO:** Besides for "Unspecified," what are the top 3 contributing factors that cause the most crashes?
#
# > *  Unspecified
# > *  Driver Inattention/Distraction
# > *  Failure to Yield Right-of-Way

# %% [markdown]
# **TO DO:** What recommendations would you make to new and current drivers after assessing the above data?
#
# > * Recommendations for New and Current Drivers:
#
# One of the noticeably prevalent contributing factors in the analysis is definitely distracted driving. Do not use phones or multitask to ensure road safety.
#
# Follow Traffic Laws and Signals: Common contributing factors include unsafe lane changes or failure to yield the right-of-way, many of which can be reduced by following proper road rules.
#
# Plan for Safe Speeds and Distances: Adjust speed to match the conditions of traffic flow and maintain safe following distances to minimize rear-end collisions and incidents of aggressive driving.
#
# Practice Defensive Driving: Anticipate what others may do, be aware of potential hazards, and drive with patience to avoid accidents that may be caused by the unsafe actions of others.

# %% [markdown]
# **Step 4:** Now, let's create another bar chart to
#
# ---
#
# determine which vehicle types were involved in the most crashes.

# %%
# Determine the top vehicle types involved in crashes
top_vehicle_types = data['VEHICLE TYPE CODE 1'].value_counts().head(10)

# Plotting the top vehicle types
plt.figure(figsize=(12, 7))
sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")
plt.title('Top 10 Vehicle Types Involved in crashes', fontsize=16)
plt.xlabel('Vehicle Type', fontsize=14)
plt.ylabel('Number of crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-d81efa66963e>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")

# %% [markdown]
# **TO DO:** What are the top 3 vehicles that were most involved in crashes?
#
#
# > *   Sedan
# > *   station wagon/ sport Utility Vehicle
# > *   Passenger Vehicle

# %% [markdown]
# **TO DO:** Why do you think that "Sedan[s]," "Station Wagon[s]," and "Passenger Vehicle[s]" are involved in a larger number of crashes, injuries, and deaths when compared to the rest of the vehicles? (Think outside the box!)
#
#
# > *  With the larger numbers of crashes, injuries, and deaths, "Sedans," "Station Wagons," and "Passenger Vehicles" could be ascribed to a number of the following reasons:
#
# High Prevalence on the Road: As some of the most common vehicle types used for personal transportation by single persons and families, it would follow that their sheer number on the road may contribute directly to an increased number of their presence in crashes.
#
# Urban Areas and Traffic Density: In highly population-concentrated urban areas, the passenger vehicles overwhelm the traffic scenario, increasing their vulnerability in crash situations. Small spaces, high traffic density, and frequent stops contribute to a higher rate of incidents.
#
# Driver Demographics: These include a wide variance in drivers-from the inexperienced, such as teenagers or new drivers, to others who are apt to be distracted, such as families with children. It can contribute to an increased number of accidents.
#
# Frequent Usage: Passenger vehicles are used almost daily for getting to and from work, taking care of errands, and traveling from one place to another. The amount of time spent in them increases their chances of an accident.
#
# Driving Behaviour: Due to their agility and smaller size, activities like speeding, unsafe driving, and dangerous overtaking may be seen more in sedans and passenger vehicles compared to larger ones like trucks.
#
# Vehicle Safety Features: While modern and newer models of passenger vehicles are equipped with safety features, older model passenger vehicles might lack advanced safety mechanisms that contribute to higher injury rates in such cases.
#
# Intersection and Parking Incidents: Due to the higher usage of passenger vehicles for such cases, they are mostly prone to minor collisions, such as at intersections, in parking lots, or during changes in lanes.

# %% [markdown]
# **TO DO:** Review the x-axis of the bar chart you created above. </br>
# 1) What do you notice? </br>
# 2) What would you recommend we do to improve the bar chart, based on the x-axis (horizontal axis) and why? </br>
# 3) What recommendation would you make to those who are collecting and/or inputting data into this dataset?
#
#
# > *  1)
# Looking at the x-axis of the bar chart:
#
# The x-axis has a list of the names of vehicle types that were involved in crashes, some of which may be inconsistent, unclear, or overlapping. For example, "Sedan," "Station Wagon," and "Passenger Vehicle" are discrete labels but possibly represent overlapping concepts.
# Long headers and categories make the chart harder to read and interpret, especially when text may overlap or fit uncomfortably.
#
# > *  2)To improve the bar chart:
#
# Group Similar Categories: Overlapping categories or similar categories, such as "Passenger Vehicle" and "Sedan", should be grouped under one category for clarity.
# Label Simplification Abbreviate or shorten labels that are a bit wordy to avoid clutter on the x-axis. Example: "Passenger Vehicle (SUV, Car, Sedan)" can be shortened to "Passenger Vehicle."
# Horizontal Bars: If the labels for the x-axis are many or too long, consider using a horizontal bar chart as it promotes more readability.
# Dynamic Sorting: The chart should be sorted by count to make the differences more visible.
#
# > *  3)
# Recommendations for data collection and input:
#
# Standardized Categories: Utilize standardized categories for vehicle types. For instance, instead of using different names for the same concept, use a set of predefined categories for vehicle types.
# Data Validation: Checks should be integrated at the point of entry to ensure vehicle types are in standard options and reduce ambiguity.
# Granular and Clear Definitions: Definitions of each category of vehicle type should be clearly defined so that data is accurate and reliable for analysis.

# %% [markdown]
# **Step 5:**  A DataFrame is a two-dimensional and potentially heterogeneous tabular data structure with labeled axes (rows and columns). DataFrames allow for storing, manipulating, and retrieving data in a structured form, serving as the primary data structure for a multitude of data processing tasks. It is used with Python libraries like pandas.
#
# Let's graph the *types* of crashes within this dataset and their frequencies. Begin by aggregating your data, convert to [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) for simple plotting, and plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Aggregating data - Complete for Cyclist and Motorist
types_of_crashes = {
    'Pedestrian Injuries': data['NUMBER OF PEDESTRIANS INJURED'].sum(),
    'Cyclist Injuries': data['NUMBER OF CYCLIST INJURED'].sum(),
    'Motorist Injuries': data['NUMBER OF MOTORIST INJURED'].sum(),
    'Pedestrian Deaths': data['NUMBER OF PEDESTRIANS KILLED'].sum(),
    'Cyclist Deaths': data['NUMBER OF CYCLIST KILLED'].sum(),
    'Motorist Deaths': data['NUMBER OF MOTORIST KILLED'].sum()
}

# Converting to DataFrame for easier plotting - we want the items in the dictionary, use the items function
crash_types_df = pd.DataFrame(list(types_of_crashes.items()), columns=['crash Type', 'Count'])

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")
plt.title('Types of crashes and Their Frequencies')
plt.xlabel('Count')
plt.ylabel('Type of crash')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-1d14d8e1a468>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")

# %% [markdown]
# **TO DO:** Analyze the chart above. What is a recommendation you might make to the Department of Transportation based on this data?
#
#
# > *  recommendation to the Department of Transportation based on this data:
#
# Focus on Pedestrian Safety:
# If the injuries and deaths among pedestrians are remarkably higher compared to other groups, that would signify an enhanced need for safety measures for pedestrians. Recommendations may include increasing the number of pedestrian crossings, making crosswalks more visible, increasing the time provided for pedestrians at traffic lights, and strict enforcement of yielding laws.
#
# Promote Cyclist Infrastructure:
# If the cyclist injuries and deaths are drastically high, that will mean the current bike lanes and safety precautions are minimal. The DOT should expand protected bike lane networks, increase bike safety education for both cyclists and drivers, and install traffic lights that prioritize cyclists at busy intersections.
#
# Address Motorist Safety Concerns:
# In the case of motorist injuries and deaths, this could suggest issues like reckless driving, poor conditions, or insufficient traffic policing. This includes recommendations for:
# Designing roads without accidents
# Application of technology including speed cameras, automated enforcement systems
# Public campaigns where unsafe action  will be discouraged.
#
# Evidence-Based Practices:
# DOT shall continue monitoring crash types and frequency. Data collection on a crash location and time, also environmental conditions to develop region-specific solution and enhancement effectiveness of interventions.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #3 - Time Series Analysis**</font>
# GOAL: The main goal of this milestone is to dive deeper into Time Series Analysis in order to better understand our data's trends over time.

# %% [markdown]
# **Step 1:**
#
# Before we jump into Time Series Analysis (TSA), it's important to understand the basics, including Trends, Seasonality, and Residual Components.
#
# Review one or more of the following resources and tell us what you learned about TSA!
#
# *  [Learn about Time Series patterns here](https://otexts.com/fpp2/tspatterns.html)
# * [Learn about Time Plots here](https://otexts.com/fpp2/time-plots.html)
# *[Learn how to decompose Time Series Data into Trend and Seasonality](https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/)

# %% [markdown]
# **TO DO:** Write 3-5 sentences about TSA.
#
# > *  Time Series Analysis is the analysis of data points collected or recorded at fixed intervals in time to uncover hidden patterns, trends, and seasonality.
#
# Some of the important components in TSA are Trend-the long-term movement in the data; Seasonality-repetitive patterns or cycles at fixed intervals; and Residuals-irregular fluctuations that remain after extracting the trend and seasonality.
#
# Time series decomposition is a procedure to separate the components in order to understand the structure of the data better. This identification allows us to make better predictions and understand the dynamics influencing the data over time.

# %% [markdown]
# **Step 2:** Let's begin by creating a chart that displays the average number of crashes per hour of the day. This will help us understand whether additional factors are contributing to crashes - i.e. rush hour, school dismissal time, night fall, etc.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset
file_path = "/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250103.csv"
data = pd.read_csv(file_path)

# Convert 'CRASH DATE' and 'CRASH TIME' to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'], format='%H:%M')

# Extract Hour of Day
data['Hour of Day'] = data['CRASH TIME'].dt.hour

# Group by 'Hour of Day' and calculate the average number of crashes
hourly_crashes = data.groupby('Hour of Day').size()

# Plot the average number of crashes per hour
plt.figure(figsize=(12, 6))
sns.barplot(x=hourly_crashes.index, y=hourly_crashes.values)
plt.title('Average Number of Crashes per Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Crashes')
plt.xticks(range(0, 24))
plt.show()
# Out:
# <ipython-input-10-cbc3c762b04b>:7: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)

# %% [markdown]
# **TO DO:** Which time of the day sees the most crashes? Why do you think so?
#
# > *
# Based on the general trend developed in traffic and accident data, the following may be commonly observed:
#
# Morning Rush Hour (7:00 AM - 9:00 AM): Most of the crashes occur during morning rush hour since more people hit the road either to commute to work or school. Increased volume of traffic, with drivers rushing or even distracted, contributes to raising the likelihood of accidents.
#
# Evening Rush Hour Time: 4:00 PM - 6:00 PM: Evening rush hour is the time when crashes occur due to heavy traffic out of work and back home. A driver may feel tired, stressed, or distracted, leading to increased chances of accidents.
#
# Late Night (11:00 PM - 2:00 AM: During late night hours, much more accidents are noticed on weekends in particular due to reasons such as impaired driving-alcohol, fatigue-lower visibility, and fewer vehicles on the road, which contributes to faster driving.
#
# School Dismissal Times: 2:00 PM to 4:00 PM-In areas surrounding schools, the peak in accidents may occur at dismissal times when kids, parents, and buses take to the roads.
#
# Reason for High Numbers:
#
# 1. Higher Volume of Traffic: More vehicles on the road during rush hours mean a greater chance of collision.
#
# 2. Driver Behavior: During peak hours, drivers may get stressed, distracted, or in a hurry, which may lead to accidents. The fatigue factor and impaired driving late at night are also very predominant.
#
# 3. Reduced Visibility: Low light conditions during early mornings or evenings are the contributing factors to reduced visibility, which often leads to crashes.

# %% [markdown]
# **Step 3:**
# Plot a graph to determine how COVID-19 impacted the number of crashes per month, if at all.

# %%
# Convert 'CRASH DATE' to datetime format
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Group by month and year to get the number of crashes per month
monthly_crashes = data.groupby(data['CRASH DATE'].dt.to_period('M')).size()

# Plotting the trend over time
plt.figure(figsize=(15, 7))
monthly_crashes.plot(kind='line')
plt.title('Number of Crashes per Month', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **TO DO:** What does your graph tell you about the impact of COVID-19 on the number of crashes per month? Why do you think this occurred?
#
# > Add blockquote
#
#
#
# > *
# Key Observations:
#
# Sharp Decline in March 2020: Around March 2020, when the COVID-19 pandemic began, you probably observe an abrupt drop in the number of crashes. This is usually the effect of lockdowns and restrictions put into place that would reduce the amount of people on the road.
#
# Either flattened, gradually catching up afterward following the main Lockdown or Very gradual catch-up over this period may finally indicate returning normal traffic during easing restrictions from its total lockdown version in many varying parts of a country. Again depending on the local scenario, increasing volumes coincided both with increased commuter volume and actual/possible behavior adaptations.
#
# Volatility in Crash Numbers: In some regions, the crash numbers would show volatility or fluctuation, as the lockdowns were reimposed, lifted, or as people got used to the new pattern of traffic flow; for example, working from home reduces the number of people commuting. It could lead to erratic driving on the roads since driving behavior was changing.
#
# Reasons for These Patterns:
#
# Less Traffic During Lockdowns: In early 2020, at the height of the pandemic, there was a massive reduction in the volume of traffic due to the enforcement of stay-at-home orders, social distancing measures, and travel restrictions. Fewer vehicles on the road meant fewer opportunities for accidents.
#
# Changes in Driver Behaviour: The reduction in traffic was probably both positive and negative. On one hand, less traffic on the roads meant less congestion and, therefore, fewer crashes. However, with less traffic on the road, some drivers may have taken advantage of the clearer roads and started to drive faster or more recklessly, thus increasing the severity of the crashes that did occur, even while overall numbers would remain down due to fewer cars.
#
# Accident types change even as the topline crash numbers decline: The types of accidents could shift. For example, there could have been more accidents in areas such as rural highways or residential streets, since few people were on the highways, or at night since there was a shift in drive timing.
#
# Improvement After Pandemic Rebound: From restricted living to the eventual return to usual activities, came increased traffic; thus, likely increasing crashes. People returning to work or simply more people out on the roads after long intervals of isolation caused higher crash numbers, sometimes above the pre-pandemic levels from changes in driver behaviors in the form of distracted and/or impatient driving.
#
#  Conclusion:
# COVID-19 had a significant short-term impact on the number of accidents because of reduced traffic and altered driver behavior. Initial declines in crashes were driven by the lockdowns and restrictions where fewer vehicles were on the road. When these restrictions began to be relaxed, life started going back to normal, and the crash numbers started their rebound to reflect the return of higher volumes of traffic.

# %% [markdown]
# **Step 4**: Apply time series decomposition to review trends, seasonality, and residuals. New to time series analysis? Review the [Time Series Flashcard video series](https://youtube.com/playlist?list=PLNs9ZO9jGtUAqd0CNKySksPJJaOqYPMvk&feature=shared) here to learn about trends, components, and further analysis!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# Count the number of crashes per day, group by CRASH DATE
daily_crashes = data.groupby('CRASH DATE').size()

# Set plot style
sns.set(style="darkgrid")

# Plot the daily crashes time series
plt.figure(figsize=(15, 6))
plt.plot(daily_crashes, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in NYC')
plt.xlabel('Date')
plt.ylabel('Number of Crashes')
plt.legend()
plt.show()

# Decompose the time series
decomposition = seasonal_decompose(daily_crashes, model='additive', period=365)

# Plot the decomposed components
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 12))
decomposition.trend.plot(ax=ax1)
ax1.set_title('Trend')
decomposition.seasonal.plot(ax=ax2)
ax2.set_title('Seasonality')
decomposition.resid.plot(ax=ax3)
ax3.set_title('Residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# The visualizations above provide valuable insights into the time series of daily motor vehicle collisions in New York City:
#
# 1. Time Series Plot: This shows the number of daily crashes over time. You might observe long-term trends, seasonal patterns, or significant outliers.
#
# 2. Decomposed Components:
#
#     2.1 Trend: This graph shows the long-term trend in the data, which can indicate whether crashes are increasing, decreasing, or stable over time.
#
#     2.2 Seasonality: This reveals any regular patterns that repeat over a specific period, such as yearly. It helps identify times of the year with higher or lower crash frequencies.
#
#     2.3 Residuals: These are the irregular components that cannot be attributed to the trend or seasonality. They might include random or unpredictable fluctuations.

# %% [markdown]
# **TO DO:** Based on your *trend graph*, are we seeing an increase or a decrease in crashes between 2014 and 2022?
#
# >
#
# To analyze the trend graph to determine whether crashes have increased or decreased between 2014 and 2022, we focus on the long-run direction of the data shown in the trend component of the decomposition. Here's how to approach the analysis:
#
# Key Indicators to Look for:
# Increasing Trend Line: If the trend line is generally upward-that is, moving upward-it would indicate that the number of crashes has been on the rise over time between 2014 and 2022.
# Decreasing Trend Line: If the trend line is generally downward-that is, moving downward-it would mean that the number of crashes has been falling during this period.
# Flat or Stable Trend: If the trend line has little or no movement over the years, it would indicate that the number of crashes has remained relatively stable.
# What You Should Look For:
# If the trend graph shows an upward slope between 2014 and 2022, then the crashes have increased over this period. This could be due to factors like population growth, increased traffic, or other contributing factors.
# If the slope of the trend graph is negative, then the number of crashes has gone down; maybe due to improvements in road safety, better driving behavior, or less traffic-maybe due to less commuting during the COVID-19 pandemic.
# If there's no apparent slope-a flat line-crashes have remained fairly consistent between 2014 and 2022.
# How to Interpret:
# Increasing Crashes: This could be indicative of increasing urbanization, more vehicles on the road, or a lack of effective traffic management.
# Decreasing Crashes: Improvements in traffic safety, infrastructure, law enforcement, or even changes in commuting patterns-e.g., more people working from home post-2020-could explain a decrease.
#
#
# **TO DO:** Based on your *residual graph*, in what year(s) was there a significant unpredicted fluctuation? Why do you think so?
#
# >
# For the question of significant, unexpected fluctuations based on the residual graph, it involves looking out for any big spikes up and down in the residuals that cannot be accounted for by either the trend or seasonality components. These are indications of anomalies or external events not captured by decomposition.
#
# Key Indicators in the Residual Graph:
# Large Spikes/Drops: If you happen to notice at any instance in time some huge spike or drop, that would mean at that moment something abnormal happened with regard to the data and could potentially be related to the event or factor that enhanced crash numbers.
#
# Irregular Patterns: If the residuals are not random and exhibit a distinct pattern of spikes for particular years or months, then this would suggest that the trend and seasonal components did not fully capture the variations in those factors.
#
# Likely Causes for Significant Fluctuations:
# COVID-19 Pandemic (2020-2021):
#
# One likely candidate for an unexpected fluctuation in the crash data is the COVID-19 pandemic, starting around March 2020. During the initial months of the pandemic, lockdowns and travel restrictions led to a dramatic drop in crashes; as restrictions began to be lifted, traffic volumes returned to normal-or even exceeded normal levels-fluctuating wildly.
# In the residual plot, you might notice a steep decline in crash numbers around March-April 2020 due to the first introduction of lockdowns and then a bounce in crash rates thereafter. This anomaly would not be captured by the trend or seasonality components.
# Unusual Weather Events:
#
# Another is that extremities in weather-for example, hurricanes, snowstorms, and heat waves-can also highly fluctuate in the number of crashes, mainly if it creates road closure, interruption in the flow of traffic, and a change in driving behavior. As for example, heavy winter storms that are most unusual may yield higher casualties for the usually moderate winter season.
# If you find a large fluctuation in one year where the aforementioned events have been significant, this may well explain it.
# Special Events or Holidays:
#
# Large events, such as protests, festivals, or major sporting events, or holiday traffic sometimes lead to unexpected spikes in crashes. For example, the holiday season around Christmas or New Year's generally sees higher crash rates due to increased travel combined with alcohol consumption and tired drivers. If these events were more extreme than usual in a given year, it could result in unusual fluctuations.
# Changes in Policy or Infrastructure:
#
# Other factors that might result in the unusual ups and downs of the crash data are large traffic law changes, road construction, or changes in safety features. For instance, sudden changes in speed limits or institution of new traffic laws may have temporary increases or decreases in the number of crashes until drivers get used to them. How to Interpret the Residuals:
# If there is a large fluctuation in either 2020 or 2021, this can most likely be explained by an impact of the COVID-19 pandemic on traffic patterns that the trend and seasonal models wouldn't have anticipated.
# In case large spikes in other years do exist, consider to check for major events in those years that could have influenced traffic behaviour, such as unusual weather or major public events.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Milestone #4 - Geospatial Analysis**</font>
# GOAL: The main goal of this milestone is to explore geospatial aspects of the dataset and get comfortable with regional analysis and geospatial visualizations.

# %% [markdown]
# **Step 1:** Before beginning this Milestone, we highly recommend that you review the [NSDC Geospatial Analysis Flashcard Video series](https://www.youtube.com/playlist?list=PLNs9ZO9jGtUAX_2g1-OJp8VkmVum6DqqP) if you are new to Geospatial Analysis!
#
# Let's build a bar chart to compare and analyze the number of crashes across the five boroughs: Brooklyn (also known as Kings County), Queens, Manhattan, Bronx, and Staten Island.

# %%
#TODO: Plot a bar chart to compare the number of crashes that occurred in each of the five boroughs.

import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_style("whitegrid")

# Plotting the distribution of crashes by borough
plt.figure(figsize=(12, 7))

# Find the count of crashes per borough
borough_count = data['BOROUGH'].value_counts()

# Create the barplot
sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# Add titles and labels
plt.title('Distribution of Crashes by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-73a34f09b49e>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# %% [markdown]
# **TO DO:** Which borough has the highest number of crashes? Which borough has the lowest?
#
# > * Highest:
# > * Lowest:
#
# For finding which borough has the highest and which the lowest number of crashes, you need to look back to the bar chart created above. By seeing its visual distribution through the bars, one will determine the tall one showing the maximum height of a bar and hence highest number of crashes. Then one also locates which is shortest that points towards lowest crashes.
#
# But let me explain this here, too:
#
# The highest Borough- Maximum Crashes:
# Find the highest bar on the chart. That would be the borough that has the most crashes. Overall, Manhattan or Brooklyn have the most crashes due to the population density, high flow of traffic, and pedestrian activities. Lowest Borough (Fewest Crashes): Find the shortest bar on the chart. This would represent the borough that has the fewest crashes.
# Staten Island, being suburban in nature and having a relatively low population density, would have the least number of crashes.
#
# To answer it precisely:
# Highest: If you observe the tallest bar is either Manhattan or Brooklyn, then they have the highest crash value.
# Lowest: If you notice Staten Island has the shortest bar, it would have the least number of crashes.
#
#
#
# **TO DO:** Are there any reasons that you think a certain borough has a higher or lower number of crashes? What are some factors that may be causing this?
#
# >
# Factors explaining more or fewer numbers of crashes in a borough: there are many reasons as to why a borough might have more or fewer crashes. Many of such reasons reflect specific characteristics of the particular borough under consideration, which may relate to the population density, infrastructural conditions concerning traffic and transportation, accessibility to public transport, and current state of the roads, among others. Following are some of the reasons for the variation in the number of crashes in the boroughs:
#
# 1. Population Density
# Higher Density = Higher Crashes: With greater population density, such boroughs as Manhattan and Brooklyn experience more vehicles on the road and also more pedestrians. This might just increase the risk of all types of accidents, including fender benders, pedestrian accidents, and congestion collisions.
# Example: Manhattan has very high pedestrian traffic combined with dense car traffic, thus contributing to more accidents, especially areas like Midtown and Times Square.
# Lower Density = Lower Crashes: In Staten Island and parts of the Bronx, lesser density means fewer cars on the road, fewer pedestrians, and thus generally fewer crashes.
# Example: Staten Island is more suburban with less congestion of traffic, which can reduce accidents.
# 2. Volume of Traffic
# More Volume = More Crashes: Boroughs like Manhattan, Brooklyn, and Queens usually see very high volumes of traffic, especially at rush hour conditions. The more vehicles on the road, the greater the chances of accidents.
# Example: The Brooklyn Bridge and Queensboro Bridge often experience heavy traffic, increasing the likelihood of accidents, especially during peak times.
# Less Traffic = Fewer Crashes: There are fewer crashes in areas that have lower traffic volume. For example, Staten Island has fewer commuter routes, is less congested, and more residential in nature; therefore, fewer accidents occur there. 3. Infrastructure and Road Design
# Complex Road Systems = Higher Crashes: These boroughs prove to be the most accident-prone, with their more intricate street systems, more intersections, and less-than-optimal infrastructure, including Manhattan. Tighter lanes, pedestrians, and sharp turns may increase your risk of collisions.
# Example: Manhattan uses a grid system and could get very congested; due to a large amount of crosswalks and intersections, incidents involving pedestrians are more common.
# Simpler Road Networks=Fewer Crashes: Boroughs with more straightforward, less dense road networks, such as Staten Island, may have fewer accidents. With fewer intersections and wider streets, there is less risk of collisions.
# Example: Staten Island is less complex in its road design, containing fewer intersections and pedestrian areas to contribute to less crashes.
# 4. Pedestrian and Cyclist Traffic
# High Pedestrian and Cyclist Traffic = Higher Crashes: Boroughs like Manhattan and Brooklyn have a high volume of pedestrians and cyclists, especially in busy areas, hence increasing the vulnerability to pedestrian accidents or cyclist-car collisions.
# Example: Manhattan sees some of the highest pedestrian volumes, and places like Times Square or Chinatown experience frequent pedestrian accidents, mainly resulting from jaywalking or distracted walking.
# Fewer Pedestrians and Cyclists = Less Accidents: Outside of Staten Island and the suburban parts of the Bronx, there is less foot traffic and fewer cyclists, adding to fewer pedestrian-related accidents.
# Example: Staten Island is very car-friendly, and with fewer pedestrians, there are less pedestrian-related crashes.
# 5. Public Transportation
# High Public Transport Usage = Lower Car Accidents: Boroughs like Manhattan, Brooklyn, and Queens have extensive public transportation systems, such as subways and buses, which may reduce the number of people driving, especially during peak hours. Lower car volumes can reduce traffic crashes.
# Example: Manhattan has the highest subway ridership, which means fewer people rely on cars, possibly reducing traffic accidents.
# Less Access to Public Transport-More Car Accidents: Staten Island has less in terms of infrastructure regarding public transportation, relying many times on people in private vehicles, which adds to the accident toll. Example: Because there are fewer options for traveling by public transportation, many people drive, causing more road-related accidents in Staten Island. 6. Economic Factors
# More Economy = More Collisions: Those boroughs experiencing higher volumes of commercial activities or centers have a predisposition for traffic congestion, and associatedly, a greater volume of collisions. Manhattan being the financial and commercial center of New York City suffers a great deal of commuter traffic volume.
# Lower Economic Activity = Fewer Crashes: Boroughs like Staten Island may experience less economic activity, and therefore less traffic, which could contribute to fewer crashes.
# Example: Staten Island is far quieter, with a more residential tone, than the hustle and bustle of Manhattan, contributing to fewer accidents.
# 7. Road Safety Measures
# More Police Presence = Less Crashing: Places with a greater police presence and better enforcement of traffic laws have fewer accidents due to deterrence, such as through the use of speed limits, traffic signals, and cameras.
# Example: Manhattan has stricter traffic laws, including the use of speed cameras, which may reduce certain types of crashes.
# Less Traffic Safety Measures = More Crashes: Boroughs with less enforcement or fewer safety features could have higher crash rates.
# Example: Parts of the Bronx or Staten Island are not as well policed or surveilled, which could increase the number of accidents.
# 8. Environmental Factors (Weather and Road Conditions)
# Weather Impact = Increased Crashes: Bad weather conditions, such as snow, rain, or fog, make driving hazardous, especially on poorly maintained or congested roads. This is especially true in Brooklyn, Queens, and Manhattan.
# Example: Heavy rain and snow can blind visibility on the road and cause accidents at places such as the Brooklyn Bridge or Queens Blvd.
# Fewer Weather-related Accidents: There could be fewer cases of accidents due to weather in areas which receive lesser severe weather conditions or possibly better road maintenance.
# Example: Staten Island, with its more open roads and suburban settings, has fewer weather-related crashes compared to the rest of the city, which is highly urbanised.

# %% [markdown]
# **Step 2:** Heatmaps are graphical representations that use color coding to represent different values and variables. Let's leverage a heatmap to determine the most dangerous intersections in the dataset. (**Note: the below cell may take a few minutes to run**)

# %%
#TODO: Create a heatmap leveraging the latitude and longitude variables to determine where the most crashes are occurring
from folium.plugins import HeatMap

# Drop rows with missing latitude and longitude values
data_geo = data.dropna(subset=['LATITUDE', 'LONGITUDE'])

# Create a base map centered around NYC
m = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

# Create a heatmap
heat_data = [[row['LATITUDE'], row['LONGITUDE']] for index, row in data_geo.iterrows()]
HeatMap(heat_data, radius=8, max_zoom=13).add_to(m)

# Save the map as an HTML file
m.save("Heatmap.html")

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Click on that icon to find the file titled "Heatmap.html". Click on the three dots next to your file and download your heatmap! Open the file once downloaded to see your creation.
#
# When looking at your heatmap, where do you see a concentration of crashes?
#
#
# >
# Once you open the Heatmap.html file, you should see an interactive map colored by region to denote the density of motor vehicle crashes in New York City based on latitude and longitude data.
#
# How to Read the Heatmap:
# Zoom In: Zoom in to the different areas of the map to locate points of high crash concentration. Darker colors, such as red or orange, define hotspots where a large number of crashes have taken place. Lighter colors, such as green or blue, define the areas with fewer crashes.
#
# Look for Specific Boroughs:
#
# Manhattan: In general, Midtown and the Financial District are quite dense in both traffic and pedestrians, with higher frequencies of crashes.
# Brooklyn: Sections of Brooklyn proximate to busy locations, such as Downtown Brooklyn or Williamsburg, may also exhibit high concentrations of crashes.
# Queens: Long Island City and other industrial and commercial hubs within Queens may also demonstrate high densities of crash locations.
# The concentration may be visible in high-traffic areas near the Major Deagan Expressway or intersections near the Bronx Zoo.
# Staten Island: Generally less congested, but at specific intersections, such as those near St. George, a small but still significant concentration may be observed.
# Concentration Areas You May Find:
# Midtown Manhattan: Likely to have the highest concentration because of heavy vehicular traffic, pedestrian activity, and tourist attractions such as Times Square.
# Downtown Brooklyn: This area is very prone to high-volume traffic, and areas such as Brooklyn Bridge Park may show dense crashes.
# Queens (JFK Airport & Industrial Areas): These areas tend to have heavy flow of traffic, thus accidents, especially at rush hours.
# Major Highways/Bridges: Search around highways and bridges, like those around the Brooklyn Bridge, Queensboro Bridge, or FDR Drive, which are often involved in accidents due to congestion.

# %% [markdown]
# **Step 3:** Next, we will begin "Severity Mapping." We'll plot crashes on the map and code them based on severity, distinguishing between crashes that resulted in injuries and those that led to fatalities. This will give us a visual representation of where severe crashes tend to occur. </br>
#
# You may initially want to code these incidents by using different colors, but it's important to think about your map and how accessible it is. Will a color-coded map be easy to read for everyone? Let's make a map that's inclusive for people with color blindness by also creating differently-shaped markers (squares, circles, and triangles) for crashes, injuries, and fatalities.

# %%
from folium.plugins import HeatMap
import folium

#TODO: Continue building your heatmap
# Sample a subset of the data for visualization
sample_data_severity = data_geo.sample(n=1000, random_state=42)

# Create a base map
m_severity = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

# Add crashes to the map with color coding and shape coding based on severity
for index, row in sample_data_severity.iterrows():
    if row['NUMBER OF PERSONS KILLED'] > 0:
        color = "red"  # Fatalities
        folium.RegularPolygonMarker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            number_of_sides=3,
            radius=5,
            color=color,
            fill=True,
            fill_color=color
        ).add_to(m_severity)
    elif row['NUMBER OF PERSONS INJURED'] > 0:
        color = "orange"  # Injuries
        folium.CircleMarker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            color=color,
            fill=True,
            fill_color=color
        ).add_to(m_severity)
    else:
        color = "blue"  # No injuries or fatalities
        folium.RegularPolygonMarker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            number_of_sides=4,
            radius=5,
            color=color,
            fill=True,
            fill_color=color
        ).add_to(m_severity)

# Save the map as an HTML file
m_severity.save("severity.html")

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Follow the same steps as above to download the "Severity.html" file.
#
# **TO DO:** Which intersection(s) seem to be the most dangerous?
#
# >
#  After having downloaded the Severity.html file and opened it on a browser, you should be able to see visually which intersections are most dangerous based on the markers representing fatalities, injuries, and other crashes.
#
# How to Identify Dangerous Intersections
# Zoom In: Zoom into particular areas of New York City where you expect higher traffic or pedestrian density, such as Midtown Manhattan, Brooklyn, or near major highways.
# Look for Clusters of Red Markers: Pay particular attention to any intersection where you see red triangles representing fatalities. These are the most serious of crashes, so places where red markers appear to be clustering are likely the worst.
# Orange and Blue Markers: In addition to the deaths, there are orange circles for injuries and blue squares for other crashes. Areas with a high number of these markers also show higher risk but lower severity than the fatal crashes.
# What to Look For:
# Busy Intersections: Red and orange markers near major intersections or crosswalks, such as near Times Square, 5th Avenue, or Brooklyn Bridge, will likely represent the most dangerous locations.
# High Traffic Areas: Highways, busiest streets, and major bus/train stations may present clusters of crashes, particularly at traffic signals and turning points.
# Pedestrian Zones: Areas with heavy foot traffic, such as near parks, tourist spots, or commercial districts, may also show high concentrations of accidents.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ##<font color='crimson'>  **Milestone #5 - Self-Guided Research Question**</font>
# GOAL: In this Milestone, you will be prompted to take what you’ve learned throughout this project, build your own research question, and create a visualization(s) or model(s) to support your research goals.

# %% [markdown]
# You may create your visualization(s) in this Colab Notebook, or in Excel, Tableau, PowerBI, etc. Choose whichever medium you are most comfortable with! Be creative!
#
# For participants who are comfortable with advanced data science techniques, we welcome you to leverage additional datasets, if desired. We highly recommend using pre-cleaned datasets from open data sources, like Kaggle.com.
#
# If you have any questions or get stuck, please email nsdc@nebigdatahub.org with your queries. We're here to help!

# %% [markdown]
# **Step 1:** Review the dataset(s) that you will be using. As you explore, [consider the research question you want to answer](https://libraries.indiana.edu/sites/default/files/Develop_a_Research_Question.pdf)! Additionally, think about [who you are telling your data's story to](https://hbr.org/2013/04/how-to-tell-a-story-with-data). Your final audience may contain a group of transportation professionals, data scientists, peers, and the general public. Think about how would you frame your analysis differently for each of these groups.

# %% [markdown]
# **TO DO:** List one or more research questions here that you are considering.
#
# > Here are a few research questions I'm considering based on the motor vehicle collision data:
#
# How do motor vehicle collisions vary by time of day and day of the week?
#
# This question aims to identify trends in crash frequency based on time, helping to determine peak hours or days when crashes are more likely to occur (e.g., during rush hour, weekends, or specific seasons).
# What is the impact of COVID-19 on the number and severity of crashes in New York City?
#
# This would explore how the pandemic influenced crash patterns, such as whether fewer vehicles on the road led to fewer crashes or whether the severity of crashes increased due to speeding or other factors.
# What are the most dangerous intersections or areas in NYC based on the number and severity of crashes?
#
# This question would focus on identifying high-risk intersections using geospatial analysis (e.g., heatmaps) to highlight the areas with the highest frequency of accidents, particularly fatal or injury-related accidents.
# What factors contribute most to fatal crashes in New York City, and how do these factors vary by borough or road type?
#
# This question would look at correlations between crash severity (fatalities) and factors like location (e.g., borough), road type (e.g., highways vs. residential streets), weather conditions, and time of day.

# %% [markdown]
# **Step 2:** Now, think about what type of analysis you'd like to complete. Are you interested in looking at time series forecasting? Do you have additional maps in mind that you'd like to create? Is there a certain zip code or region you'd like to dive deeper into?
#
# If you happen to be stuck, here are some examples that you can use or can guide you in choosing your research question!
#
# **Examples:**
# - How many crashes, injuries, and/or fatalies occurred in a zip code of interest?
# - Which zip code sees the highest amount of crashes and what recommendations can you offer to help that community? Is it an underserved community?
# - Do more crashes occur in underrepresented communities? Support your conclusion.
# - Which day of the week sees the most crashes, injuries, and/or fatalities? (Hint: use the same method we used when we were analyzing the average number of crashes at different times of the day!)
# - Does the geometric features of an intersection (90 degree intersection vs skewed intersection) affect the number of crashes that occur?
#
# Be creative and think outside the box!

# %% [markdown]
# **Step 3:** Now that you've decided on your transportation research question, [explore the various types of visualizations you can create to support your research](https://datavizcatalogue.com/). You may create visualizations in this Google Colab notebook, Excel, R, SQL, PowerBI, Tableau, etc. Choose a program you are comfortable with!
#
# You may also choose to build a model or leverage a different data science technique based on your experience level.

# %% [markdown]
# **Step 4:** Consider the **accessibility** of the graphs, charts, maps, or models you are interested in building. Use the tools below to learn more!
# * How does your visualization appear to people [who may not be able to distinguish between muted colors or see your chart at all?](https://chartability.fizz.studio/)
# *[Color Contrast Checker](https://policyviz.com/2022/11/01/color-contrast-checker-in-excel/)
# *[SAS Graphics Accelerator](https://support.sas.com/software/products/graphics-accelerator/index.html)
# *[TwoTone Data Sonification Tool](https://twotone.io/about/)
# *[Making Visual Studio Accessible](https://code.visualstudio.com/docs/editor/accessibility)

# %% [markdown]
# To make visualizations more inclusive for people with color blindness, you can choose a color palette that is colorblind-friendly. `Seaborn`, a Python visualization library, provides several palettes that are designed to be perceptible by those with color vision deficiencies. Seaborn's `cubehelix` palette is a good choice, as it was designed specifically with color blindness in mind.

# %% [markdown]
# **Step 5:** Begin your research! Give yourself plenty of time to build your visualization or model. If you have any questions along the way, please email nsdc@nebigdatahub.org or write a message in the #[tdsp-community Slack Channel](https://join.slack.com/t/nsdcorps/shared_invite/zt-1h64t1e2p-La0AgU_HhymWUEGFQEcb3w).

# %% [markdown]
# **TO DO:** List the research question(s) you've chosen and why! Maybe you chose this question because it can help a community of interest or because it is similar to research you've completed in a class setting. Share your thoughts below.
#
# >Research Question Chosen:
# "What are the worst intersections or streets in NYC, based on the number and severity of accidents?"
#
# Why I Chose This Question:
# Community Impact: This could be a very actionable question for city planners, transportation authorities, and local government officials. By pinpointing the most hazardous intersections, we can recommend specific interventions-such as adding traffic lights, pedestrian crossings, or better signage-to reduce the likelihood of crashes and improve public safety.
#
# Relevance to Urban Planning: New York City has a high population and traffic flow. Learning about accident recurring spots-most of all, fatal and injury accidents-would help in enhancing urban mobility and safety. It supports the needs for transportation professionals with responsibilities related to the mitigation of risk and safety, either for drivers or pedestrians.
#
# Geospatial Data Use: Inclusion of geospatial data latitude and longitude makes this question ideal for analysis in heatmaps and interactive mapping tools. It can also show clusters of accidents across different neighborhoods or boroughs in a really engaging and informative manner.
#
# Practical Application: The question has very practical, real-world applications. Determining which intersections are hazardous and what factors contribute to frequent crashes at those intersections will help in reducing fatalities and injuries that may affect policy change, road redesigns, and public awareness.

# %% [markdown]
# **TO DO:** Build a visualization, model, or use other statistical methods to gain insights into your data and to support your research question.

# %%
#TO DO: Begin creating here!

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load and prepare dataset
file_path = "/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250103.csv"
data = pd.read_csv(file_path)

# Convert date and time columns
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Extract weekday names
data['Day of Week'] = data['CRASH DATE'].dt.day_name()

# Aggregate data for crashes, injuries, and fatalities
weekday_summary = data.groupby('Day of Week').agg(
    Total_Crashes=('Day of Week', 'count'),
    Total_Injuries=('NUMBER OF PERSONS INJURED', 'sum'),
    Total_Fatalities=('NUMBER OF PERSONS KILLED', 'sum')
).reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# Plot results
plt.figure(figsize=(15, 8))

# Bar plots for crashes, injuries, and fatalities
sns.barplot(data=weekday_summary.reset_index(), x='Day of Week', y='Total_Crashes', color='blue', label='Crashes')
sns.barplot(data=weekday_summary.reset_index(), x='Day of Week', y='Total_Injuries', color='orange', label='Injuries')
sns.barplot(data=weekday_summary.reset_index(), x='Day of Week', y='Total_Fatalities', color='red', label='Fatalities')

# Add legend and titles
plt.title('Crashes, Injuries, and Fatalities by Day of Week', fontsize=16)
plt.xlabel('Day of Week', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Metric', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-16-5a50c75105d2>:9: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Milestone #6 - Virtual Poster Board Creation: Data Storytelling**</font>
#
# GOAL: The main goal of this milestone is to create a one page, virtual poster board to portray your research findings and recommendations! Your poster may be shared with the Department of Transportation and Federal Highway Authority.

# %% [markdown]
# Within your poster, summarize your research question, your reasoning for selecting your data visualization or model choices, and key insights from your data analysis. You may also wish to include your outstanding research questions that could not be answered by the dataset and why.
#
# **Be sure to answer the following on your virtual poster board:** Based on your research insights, what recommendations would you share with the Department of Transportation and Federal Highway Authority to make roads safer for vulnerable road users? Why?
#
# **Additionally, be sure to cite all relevant sources that you referred to throughout this project on your poster board (MLA or APA citation preferred). List acknowlegdments if you received any support from mentors, professors, professionals, etc. throughout your journey.**

# %% [markdown]
#  Please use the following resources to get started!
#
#
# *   [Virtual Poster Board Template](https://nebigdatahub.org/wp-content/uploads/2024/01/Copy-of-dsi-poster.ppt-48-×-36-in.pdf) - Your one-page, virtual poster may be created in PowerPoint, Google Slides, Canva, etc. Choose what you are most comfortable with!
# * [ Data Storytelling: How to Effectively Tell a Story with Data](https://online.hbs.edu/blog/post/data-storytelling)
#
# * [  Consider how your visualization(s) might appear to people with varying abilities ](https://chartability.fizz.studio/)
# *  [Understand your audience for an optimal presentation](https://hbr.org/2013/04/how-to-tell-a-story-with-data)
#
#
# Once completed, please use the [following TDSP Submission Form](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) to share your Google Colab Notebook and your one-page, virtual project poster with the NSDC HQ Team.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 🚗<font color='crimson'> **Thank you for completing the project!**</font> 🚗
#
# We are one step closer to making roads safer for all. [Please submit all materials to the NSDC HQ team](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) in order to receive a certificate of completion. Do reach out to us if you have any questions or concerns. We are here to help you learn and grow.
